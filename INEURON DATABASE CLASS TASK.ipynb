# %%
import mysql.connector as connection
import pandas as pd
import sqlalchemy 


mydb = connection.connect(host="localhost", database='ineurontask', user="root", passwd="Sunny@1997",auth_plugin='mysql_native_password')

# %% [markdown]
# ques3- read these dataset in pandas as a dataframe

# %%
query = "Select * from attributedatas;"
result_dataFrame = pd.read_sql(query,mydb)
print(result_dataFrame)
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           None     chiffon     ruffles
# ...

# %%
query = "Select * from dresssales;"
result_dataFrame = pd.read_sql(query,mydb)
print(result_dataFrame)
# Out:
#        Dress_ID  29/8/2013  31/8/2013  09-02-2013  09-04-2013  09-06-2013  \
# 0    1006032852       2114       2274        2491        2660        2727
# 1    1212192089        151        275         570         750         813
# 2    1190380701          6          7           7           7           8
# 3     966005983       1005       1128        1326        1455        1507
# 4     876339541        996       1175        1304        1396        1432
# ..          ...        ...        ...         ...         ...         ...
# 493   713391965          0          0           0         560         554
# 494   722565148          0          0           0         875         866
# 495   532874347          0          0           0         734         728
# 496   655464934          0          0           0         254         259
# 497   919930954          0          0           0         538         545
#
#      09-08-2013  09-10-2013  09-12-2013  14/9/2013  ...  MyUnknownColumn_[1]  \
# ...

# %%
df1= pd.read_csv(r"E:\Downloads\attribute1.csv")
df2= pd.read_csv(r"E:\Downloads\Dress Sales1.csv")

# %% [markdown]
# ques2- Convert attribute dataset in json format

# %%
ds = df1.to_json("attributedatas.json")

# %% [markdown]
#  QUES -6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID

# %%
pd.read_sql('select * from attributedatas as a left join dresssales as d on(a.Dress_ID=d.Dress_ID);',mydb)
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 545   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 546   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 547   532874347   Casual  Average     4.7     M  Summer     v-neck
# 548   655464934   Casual  Average     4.6     L  winter  boat-neck
# 549   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  ... MyUnknownColumn_[1]  \
# 0      sleevless    empire           None  ...
# ...

# %% [markdown]
# QUES 7. Write a sql query to find out how many unique dress that we have based on dress id

# %%
pd.read_sql('select count(distinct(Dress_ID)) from attributedatas;',mydb)
# Out:
#    count(distinct(Dress_ID))
# 0                        475

# %% [markdown]
#   QUES - 8. Try to find out how mnay dress is having recommendation 0

# %%
pd.read_sql('select count(Dress_ID) from attributedatas where Recommendation=0;',mydb)
# Out:
#    count(Dress_ID)
# 0              290

# %% [markdown]
# QUES 9. Try to find out total dress sell for individual dress id

# %%
df2=pd.read_sql('select * from dresssaleS',mydb)
df2['total_sale']=df2[df2.columns[-23:-1]].sum(axis=1)
df2[['Dress_ID','total_sale']]
# Out:
# C:\Users\HP\AppData\Local\Temp/ipykernel_25768/1496376611.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2['total_sale']=df2[df2.columns[-23:-1]].sum(axis=1)
#        Dress_ID  total_sale
# 0    1006032852       41589
# 1    1212192089       38184
# 2    1190380701         121
# 3     966005983       21152
# 4     876339541       26104
# ..          ...         ...
# 493   713391965        4172
# 494   722565148        9821
# 495   532874347        6294
# 496   655464934        2784
# 497   919930954        7151
#
# [498 rows x 2 columns]

# %% [markdown]
# QUES-10. Try to find out a third highest most selling dress id

# %%
df2[['Dress_ID','total_sale']].sort_values('total_sale').iloc[-3]
# Out:
# Dress_ID      749031896
# total_sale        41477
# Name: 13, dtype: int64

# %%
pwd
# Out:
# 'C:\\Users\\HP'
